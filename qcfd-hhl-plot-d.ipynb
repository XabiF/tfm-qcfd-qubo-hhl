# %%
import numpy as np
import matplotlib.pyplot as plt
import datafit

N = np.array([
    5,
    6, 
    7, 
    8, 
    9,
    # 10,
])

b = np.array([
    97,
    364,
    822,
    1894,
    3450,
    # 0
])

d = 2*b - 1

# Note: b values were manually extracted from sim plot debug messages

plt.figure(figsize=(6, 4))
plt.plot(N, d, marker='o', linestyle='-', color='blue')
plt.xlabel('N')
plt.ylabel('d')
plt.grid(True)
plt.tight_layout()
plt.savefig("d.png")
plt.show()
datafit.fit_log(N**2, d)
# Out:
# Linear Fit:   y = 120.0567x + -3473.0936
# Quadratic Fit: y = 1.7466x² + -65.3824x + 751.9243
# Cubic Fit:    y = -0.0022x³ + 2.1022x² + -82.7275x + 1006.7495
# Quartic Fit:  y = -0.0013x⁴ + 0.2685x³ + -17.9809x² + 539.7490x + -5752.1789
# Quintic Fit:  y = -0.0000x⁵ + 0.0012x⁴ + 0.0210x³ + -6.3243x² + 277.0348x + -3490.4548
# Exponential Fit (x scaled):
# y = 194.7265 * e^(3.5879 * (x / max(x)))
# x log x Fit: y = 28.3312 * (x+-25.0000) log(x+-25.0000) + -24.6429
# x^4 log x Fit: y = 0.000034 * x^4 log(x) + 658.954344
# Linear    : R² = 0.9454, MSE = 328622.0891
# Quadratic : R² = 0.9994, MSE = 3764.9829
# Cubic     : R² = 0.9994, MSE = 3661.0552
# Quartic   : R² = 1.0000, MSE = 0.0000
# Quintic   : R² = 1.0000, MSE = 0.0000
# Exponential: R² = 0.9848, MSE = 91427.0902
# x log x   : R² = 0.9789, MSE = 127030.1493
# x^4 log x : R² = 0.9693, MSE = 184902.4348
# c:\Users\xfernandez\OneDrive - AYESA\Escritorio\TFM\QCFD\fit.py:124: RankWarning: Polyfit may be poorly conditioned
# ...
